# %%
# Clone Notebook to access mylib
# !rm -rf JahnaviM-CloudHostedNotebook/*
# !git clone https://github.com/nogibjj/JahnaviM-CloudHostedNotebook.git
# %cd JahnaviM-CloudHostedNotebook
# Out:
# Cloning into 'JahnaviM-CloudHostedNotebook'...
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 25 (delta 1), reused 9 (delta 1), pack-reused 15 (from 1)
# Receiving objects: 100% (25/25), 46.78 MiB | 22.73 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# /root/JahnaviM-CloudHostedNotebook

# %%
# import libraries/methods
from IPython.display import display
from mylib.lib import read_df, summarize_df, hist_time_occ

# %%
# read data
df = read_df("Crime_Data_from_2020_to_Present.csv.zip")
print('Crime Dataset Loaded from zipped csv file.')
# Out:
# Crime Dataset Loaded from zipped csv file.

# %%
# get summary stats
print('Summary Statistics:')
display(summarize_df(df))
# Out:
# Summary Statistics:
#               DR_NO       TIME OCC           AREA    Rpt Dist No  \
# count  9.744770e+05  974477.000000  974477.000000  974477.000000
# mean   2.195654e+08    1338.771108      10.705048    1116.939579
# std    1.285558e+07     651.717033       6.106287     610.729787
# min    8.170000e+02       1.000000       1.000000     101.000000
# 25%    2.106058e+08     900.000000       5.000000     589.000000
# 50%    2.208087e+08    1420.000000      11.000000    1141.000000
# 75%    2.309064e+08    1900.000000      16.000000    1617.000000
# max    2.499253e+08    2359.000000      21.000000    2199.000000
#
#             Part 1-2         Crm Cd       Vict Age      Premis Cd  \
# count  974477.000000  974477.000000  974477.000000  974463.000000
# mean        1.405166     500.748719      29.168748     306.098905
# std         0.490924     206.374691      21.954094     218.651133
# min         1.000000     110.000000      -4.000000     101.000000
# 25%         1.000000     331.000000       0.000000     101.000000
# 50%         1.000000     442.000000      30.000000     203.000000
# 75%         2.000000     626.000000      44.000000     501.000000
# max         2.000000     956.000000     120.000000     976.000000
#
#        Weapon Used Cd       Crm Cd 1      Crm Cd 2     Crm Cd 3   Crm Cd 4  \
# count   325782.000000  974466.000000  68760.000000  2309.000000   64.00000
# mean       363.797727     500.501656    958.139311   984.192724  991.21875
# std        123.664671     206.171549    110.261645    51.506344   27.06985
# min        101.000000     110.000000    210.000000   310.000000  821.00000
# 25%        311.000000     331.000000    998.000000   998.000000  998.00000
# 50%        400.000000     442.000000    998.000000   998.000000  998.00000
# 75%        400.000000     626.000000    998.000000   998.000000  998.00000
# max        516.000000     956.000000    999.000000   999.000000  999.00000
#
#                  LAT            LON      TimeOccHr
# count  974477.000000  974477.000000  974477.000000
# mean       33.995066    -118.079971      13.506428
# std         1.643523       5.696584       6.520273
# min         0.000000    -118.667600       0.016667
# 25%        34.014600    -118.430600       9.000000
# 50%        34.058900    -118.322500      14.333333
# 75%        34.164900    -118.273900      19.000000
# max        34.334300       0.000000      23.983333

# %%
# show hist plot
print('Histogram Plot:')
hist_time_occ(df)
# Out:
# Histogram Plot:
# 'Histogram Loaded'
